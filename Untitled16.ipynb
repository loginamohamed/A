# %% [markdown]
# <a href="https://colab.research.google.com/github/loginamohamed/A/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *** Python NumPy Exercise***

# %% [markdown]
# **Exercise 1**: Create a 4X2 integer array and Prints its attributes
# Note: The element must be a type of unsigned int16. And print the following
# Attributes: –
#  The shape of an array.
#  Array dimensions.
#  The Length of each element of the array in bytes.

# %%
import numpy as np
#The empty() function is used to create a new array of given shape and type, without initializing entries.
a=np.empty([4, 2], dtype=np.uint16)
print(a)
x=a.shape
y=a.ndim
z=a.itemsize
print("shape of an array",x)
print("Array dimensions",y)
print("The Length of each element of the array in bytes",z)
# Out:
# [[2 0]
#  [0 0]
#  [3 0]
#  [0 0]]
# shape of an array (4, 2)
# Array dimensions 2
# The Length of each element of the array in bytes 2

# %% [markdown]
# **Exercise 2:** Create a 5X2 integer array from a range between 100
# to 200 such that the difference between each element is 10
# Expected Output:

# %%
arr = np.arange(100, 200, 10)
arr = arr.reshape(5,2)
print (arr)
# Out:
# [[100 110]
#  [120 130]
#  [140 150]
#  [160 170]
#  [180 190]]

# %% [markdown]
# **Exercise 3:** Following is the provided numPy array. Return array of
# items by taking the third column from all rows

# %%
x = np.array([[11 ,22, 33], [44, 55, 66], [77, 88, 99]]) 
print(x)
print("--------")

z = x[...,2]
print(z)
# Out:
# [[11 22 33]
#  [44 55 66]
#  [77 88 99]]
# --------
# [33 66 99]

# %% [markdown]
# **Exercise 4:** Return array of odd rows and even columns from
# below numpy array

# %%
arr = np.array([[3 ,6, 9, 12], [15 ,18, 21, 24], [27 ,30, 33, 36], [39 ,42, 45, 48], [51 ,54, 57, 60]]) 
print("Odd rows and Even columns")
xarr = arr[::2, 1::2]
print(xarr)
# Out:
# Odd rows and Even columns
# [[ 6 12]
#  [30 36]
#  [54 60]]

# %% [markdown]
# **Exercise 5:** Create a result array by adding the following two
# NumPy arrays. Next, modify the result array by calculating the
# square of each element

# %%
x = np.array([[5, 6, 9], [21 ,18, 27]])
z = np.array([[15 ,33, 24], [4 ,7, 1]])

sum = x+ z
print(sum)
print("---------")


for i in np.nditer(sum, op_flags = ['readwrite']):
   i[...] = i*i
print("\nmodify the result array by calculating the square of each element\n")
print(sum)
# Out:
# [[20 39 33]
#  [25 25 28]]
# ---------
#
# modify the result array by calculating the square of each element
#
# [[ 400 1521 1089]
#  [ 625  625  784]]

# %% [markdown]
# **Python Pandas Exercise**

# %% [markdown]
# Exercise 1: Clean the dataset and update the CSV file?

# %%
import pandas as pd
pd.options.display.max_rows=607
df=pd.read_csv('ds_salaries.csv')
df.dropna(inplace=True)
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# 5             5       2020               EN              FT
# 6             6       2020               SE              FT
# 7             7       2020               MI              FT
# 8             8       2020               MI              FT
# 9             9       2020               SE              FT
# 10           10       2020               EN              FT
# 11           11       2020               MI              FT
# 12           12       2020               EN              FT
# 13           13       2020               MI              FT
# 14           14       2020               MI              FT
# ...

# %% [markdown]
# **Exercise 2:** Find the most expensive car company name?

# %%
print("The most expensive =")
print(df['salary_in_usd'].max())
# Out:
# The most expensive =
# 600000

# %% [markdown]
# **Exercise 3:** Print All Toyota Cars details?

# %%
dfx=df.groupby('job_title')
dfx.get_group('Data Scientist')
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0             0       2020               MI              FT  Data Scientist
# 7             7       2020               MI              FT  Data Scientist
# 10           10       2020               EN              FT  Data Scientist
# 11           11       2020               MI              FT  Data Scientist
# 12           12       2020               EN              FT  Data Scientist
# 32           32       2020               SE              FT  Data Scientist
# 40           40       2020               MI              FT  Data Scientist
# 46           46       2020               MI              FT  Data Scientist
# 48           48       2020               MI              FT  Data Scientist
# 56           56       2020               MI              FT  Data Scientist
# 57           57       2020               MI              FT  Data Scientist
# ...

# %% [markdown]
# **Exercise 4:** Count total cars per company?

# %%
print("Count total")
df['job_title'].value_counts()
# Out:
# Count total
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# ...

# %% [markdown]
# **Exercise 6:** Find each company’s Higesht price car?

# %%
print("Higesht price")
dfz=df.groupby('job_title')
dfz['job_title',"salary_in_usd"].max()
# Out:
# Higesht price
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                          job_title  \
# job_title
# 3D Computer Vision Researcher                        3D Computer Vision Researcher
# AI Scientist                                                          AI Scientist
# Analytics Engineer                                              Analytics Engineer
# Applied Data Scientist                                      Applied Data Scientist
# Applied Machine Learning Scientist              Applied Machine Learning Scientist
# BI Data Analyst                                                    BI Data Analyst
# Big Data Architect                                              Big Data Architect
# ...
